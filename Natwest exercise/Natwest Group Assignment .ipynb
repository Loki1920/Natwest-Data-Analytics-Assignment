# %% [markdown]
# # In this notebook , I have analyzed the given data by Natwest, perform  EDA(using matplotlib and seaborn) and pandas profiling .

# %%
# structure_file_df dataFrame
import pandas as pd

structure_file_path = r"C:\Users\lucky\Machine Learning Projects\Natwest exercise\HealthApp_2k.log_structured.csv"
structure_file_df = pd.read_csv(structure_file_path)

structure_file_df = structure_file_df.drop("LineId",axis = 1)

structure_file_df
# Out:
#                        Time                 Component       Pid  \
# 0     20171223-22:15:29:606                  Step_LSC  30002312
# 1     20171223-22:15:29:615                  Step_LSC  30002312
# 2     20171223-22:15:29:633  Step_StandReportReceiver  30002312
# 3     20171223-22:15:29:635                  Step_LSC  30002312
# 4     20171223-22:15:29:635     Step_StandStepCounter  30002312
# ...                     ...                       ...       ...
# 1995   20171224-0:58:53:985                  Step_LSC  30002312
# 1996    20171224-0:59:7:581                  Step_LSC  30002312
# 1997     20171224-1:0:0:794                  Step_LSC  30002312
# 1998     20171224-1:1:0:935                  Step_LSC  30002312
# 1999    20171224-1:2:35:789                  Step_LSC  30002312
#
#                                                 Content EventId  \
# 0                               onStandStepChanged 3579     E42
# 1                         onExtend:1514038530000 14 0 4     E39
# ...

# %%
# templates_df dataFrame
templates_file = "HealthApp_2k.log_templates.csv"
templates_df = pd.read_csv(templates_file)
templates_df
# Out:
#    EventId                                      EventTemplate
# 0       E1  Alarm uploadStaticsToDB totalSteps=<*>:<*>:<*>...
# 1       E2  bulkSaveDetailHiHealthData() size = <*>,totalT...
# 2       E3       calculateAltitudeWithCache totalAltitude=<*>
# 3       E4       calculateCaloriesWithCache totalCalories=<*>
# 4       E5  checkCurrentDay a new day comes , reset basicS...
# ..     ...                                                ...
# 70     E71          tryToReloadTodayBasicSteps<*>|<*>|<*>|<*>
# 71     E72  upLoadOneMinuteDataToEngine time=<*>,<*>,<*>,<...
# 72     E73              uploadStaticsToDB failed message=true
# 73     E74  uploadStaticsToDB() onResult  type = <*> obj=true
# 74     E75                             writeDataToDB size <*>
#
# [75 rows x 2 columns]

# %%
# log_df  data 
log_file = "HealthApp_2k.log"
log_columns = ["Time", "Component", "Pid", "Content","EventId","EventTemplate","LineId" ]
log_df = pd.read_csv(log_file, sep='|', header=None, names=log_columns)
log_df = log_df.drop("LineId",axis = 1)
log_df[["EventId","EventTemplate"]] = structure_file_df[["EventId","EventTemplate"]]
log_df
# Out:
#                        Time                 Component       Pid  \
# 0     20171223-22:15:29:606                  Step_LSC  30002312
# 1     20171223-22:15:29:615                  Step_LSC  30002312
# 2     20171223-22:15:29:633  Step_StandReportReceiver  30002312
# 3     20171223-22:15:29:635                  Step_LSC  30002312
# 4     20171223-22:15:29:635     Step_StandStepCounter  30002312
# ...                     ...                       ...       ...
# 1995   20171224-0:58:53:985                  Step_LSC  30002312
# 1996    20171224-0:59:7:581                  Step_LSC  30002312
# 1997     20171224-1:0:0:794                  Step_LSC  30002312
# 1998     20171224-1:1:0:935                  Step_LSC  30002312
# 1999    20171224-1:2:35:789                  Step_LSC  30002312
#
#                                                 Content EventId  \
# 0                               onStandStepChanged 3579     E42
# 1                         onExtend:1514038530000 14 0 4     E39
# ...

# %%
# checking for  missing value 
missing_values = log_df.isnull().sum()
missing_values
# Out:
# Time             0
# Component        0
# Pid              0
# Content          0
# EventId          0
# EventTemplate    0
# dtype: int64

# %%
log_df.describe(include='all')
# Out:
#                       Time Component         Pid  \
# count                 2000      2000      2000.0
# unique                1711        20         NaN
# top     20171223-23:7:6:86  Step_LSC         NaN
# freq                    12       710         NaN
# mean                   NaN       NaN  30002312.0
# std                    NaN       NaN         0.0
# min                    NaN       NaN  30002312.0
# 25%                    NaN       NaN  30002312.0
# 50%                    NaN       NaN  30002312.0
# 75%                    NaN       NaN  30002312.0
# max                    NaN       NaN  30002312.0
#
#                                              Content EventId  \
# count                                           2000    2000
# unique                                          1179      75
# top     calculateAltitudeWithCache totalAltitude=240     E39
# freq                                             217     273
# mean                                             NaN     NaN
# ...

# %%
# Graphical plot log_df data 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime


# Convert the timestamp column to datetime format
log_df['Time'] = pd.to_datetime(log_df['Time'], format='%Y%m%d-%H:%M:%S:%f')

# Extract date, day of the week, and hour columns
log_df['Date'] = log_df['Time'].dt.date
log_df['DayOfWeek'] = log_df['Time'].dt.day_name()
log_df['Hour'] = log_df['Time'].dt.hour

# Plot the number of steps taken on a daily basis
daily_steps = log_df[log_df['Component'] == 'Step_LSC'].groupby('Date').size()
daily_steps.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Daily Steps')
plt.xlabel('Date')
plt.ylabel('Number of Steps')
plt.show()

# Plot the active times during the day
hourly_activity = log_df.groupby('Hour').size()
hourly_activity.plot(kind='bar', figsize=(10, 6), color='orange')
plt.title('Hourly Activity')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Events')
plt.show()

# Identify workout sessions based on certain events
workout_sessions = log_df[log_df['EventTemplate'].isin(['E42', 'E39'])]
workout_sessions['Duration'] = workout_sessions['Time'].diff().dt.total_seconds()
total_workout_time = workout_sessions['Duration'].sum()
print(f'Total workout time: {total_workout_time} seconds')

# Visualize workout sessions
sns.lineplot(x='Time', y='Duration', data=workout_sessions)
plt.title('Workout Sessions')
plt.xlabel('Time')
plt.ylabel('Duration (seconds)')
plt.show()
# Out:
# Total workout time: 0.0 seconds

# %%
# Installing dependencies 
pip install ydata-profiling
# Out:
# ...
#
# ...

# %%
from pandas_profiling import ProfileReport
import ydata_profiling
# Out:
# C:\Users\lucky\AppData\Local\Temp\ipykernel_10980\221062108.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
# Analyzing structure_file_df using pandas profiling  
profile = ProfileReport(structure_file_df)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-12-17 16:24:12.698221&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
